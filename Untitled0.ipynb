# %% [markdown]
# <a href="https://colab.research.google.com/github/Murad039/Machine-learning/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import ridge/lasso
scores = []

for a in [0.01, 0.1, 10, 100, 1000]
  ridge = ridge(alpha = a)
  ridge.fit(X_train, y_train)
  y_pred = ridge.predict(X_test)
  scores.append(ridge.score(X_test, y_test))
print(scores)

# %% [markdown]
# lasso regression for feature selection

# %%
from sklear.linear_moodel import lasso

X = database_df.drop["glucose", axis = 1].values
y = database_df["glucose"].values

names = database_df.drop("glucose", axis = 1).columns

lasso = lasso(alpha = 0.1)

lasso_coef = lasso.fit(X, y).coef4

plt.bar(names, lasso_coef)
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# confustion metrics in scikit learn

# %%
from sklearn.metrics import classification_report, confusion_matrix

knn = KNeighborsClassifier(n_neighbors = 7)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 42)

knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

print(confusion_matrix(y_test, y_pred))

# %% [markdown]
# GridSearch cv in **scikitlearn**
# ```

# %%
from sklearn.model_selection import GridSearchCV

kf = KFold(n_splits = 5, suffle = True, random_state = 42)

param_grid = { "alpha": np.arange(0.0001,1,10), "solver": ["sag", "lsqr"]}

ridge = Ridge()

ridge_cv = GridSearchCV(ridge, param_grid, cv = kf)

ridge_cv.fit(X_train, y_train)

print(ridge_cv.best_params_, ridge_cv.best_score_)

# %% [markdown]
# random search cv

# %%
from sklearn.model_selection import RandomizedSearch

kf = KFold(n_splits = 5, suffle = True, random_state = 43)
param_grid = { "alpha": np.arange(0.0001,1,10), "solver": ["sag", "lsqr"]}

ridge = Ridge()

ridge_cv = RandomizedSearchCV(ridge, param_grid, cv = kf)

ridge_cv.fit(X_train, y_train)

print(ridge_cv.best_params_, ridge_cv.best_score_)
